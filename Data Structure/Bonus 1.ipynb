# %%
a=[1,2,3,4,5]

# %%
b=[6,7,4,8,9]

# %%
a+b
# Out:
# [1, 2, 3, 4, 5, 6, 7, 4, 8, 9]

# %%
c=0

# %%
for i in range(len(b)):
    print(a[c]+b[c])
    c=c+1
# Out:
# 7
# 9
# 7
# 12
# 14

# %%
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in enumerate(b):
    print(i)
# Out:
# (0, 6)
# (1, 7)
# (2, 4)
# (3, 8)
# (4, 9)

# %%
for i,j in enumerate(a):
    print(i,j)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %% [raw]
# this is upacking from the tuple
# in the above program
# and the index and values stoers on the i and j variable

# %%
for i,j in enumerate(a):
    print(j+b[i])
# Out:
# 7
# 9
# 7
# 12
# 14

# %%
for i in zip(a,b):
    print(i)
# Out:
# (1, 6)
# (2, 7)
# (3, 4)
# (4, 8)
# (5, 9)

# %%
d={'name':'Aastha','Roll no':1,'age':22}

# %%
d
# Out:
# {'name': 'Aastha', 'Roll no': 1, 'age': 22}

# %%
fruits={'apple','banana','orange'}

# %%
d.fromkeys(fruits,50)
# Out:
# {'orange': 50, 'banana': 50, 'apple': 50}

# %%
s='broadwaysinfosys'

# %%
from collections import Counter

# %%
Counter(s)
# Out:
# Counter({'b': 1,
#          'r': 1,
#          'o': 2,
#          'a': 2,
#          'd': 1,
#          'w': 1,
#          'y': 2,
#          's': 3,
#          'i': 1,
#          'n': 1,
#          'f': 1})

# %%
import collections as col

# %%
help(col)
# Out:
# Help on package collections:
#
# NAME
#     collections
#
# DESCRIPTION
#     This module implements specialized container datatypes providing
#     alternatives to Python's general purpose built-in containers, dict,
#     list, set, and tuple.
#
#     * namedtuple   factory function for creating tuple subclasses with named fields
#     * deque        list-like container with fast appends and pops on either end
#     * ChainMap     dict-like class for creating a single view of multiple mappings
#     * Counter      dict subclass for counting hashable objects
#     * OrderedDict  dict subclass that remembers the order entries were added
#     * defaultdict  dict subclass that calls a factory function to supply missing values
#     * UserDict     wrapper around dictionary objects for easier dict subclassing
#     * UserList     wrapper around list objects for easier list subclassing
#     * UserString   wrapper around string objects for easier string subclassing
#
# PACKAGE CONTENTS
# ...

# %%
ls
# Out:
#  Volume in drive H is New Volume
#  Volume Serial Number is 2C91-E59B
#
#  Directory of H:\python\Data Structure
#
# 04/10/2019  08:05 AM             5,754 (pattern)Day5.ipynb
# 04/08/2019  08:02 AM            10,190 (Unpacking.Slicing.Indexing.Steppping)day3.ipynb
# 04/16/2019  10:24 AM    <DIR>          .
# 04/16/2019  10:24 AM    <DIR>          ..
# 04/16/2019  10:08 AM    <DIR>          .ipynb_checkpoints
# 04/16/2019  07:55 AM             9,906 9(Map,Reduce,Filter).ipynb
# 04/16/2019  10:24 AM             5,404 Bonus 1.ipynb
# 04/12/2019  06:51 AM            21,780 Day6(set).ipynb
# 04/15/2019  08:57 PM            38,523 Day7(Dictionary).ipynb
# 04/16/2019  10:17 AM           105,625 dictionary (2).ipynb
# 04/08/2019  08:02 AM                38 linkforscreenshot
# 04/13/2019  07:27 PM            55,888 List(D1).ipynb
# 04/09/2019  08:06 AM             4,588 Loop Statement(Day4).ipynb
# 04/15/2019  08:57 PM             1,100 note(d2)
# ...

# %%
pwd
# Out:
# 'H:\\python\\Data Structure'

# %%
s='I love python'

# %%
s
# Out:
# 'I love python'

# %%
s.split()
# Out:
# ['I', 'love', 'python']

# %%
s='I-love-python'

# %%
s.split()
# Out:
# ['I-love-python']

# %%
s.split('o')
# Out:
# ['I-l', 've-pyth', 'n']

# %%
'love' in s
# Out:
# True

# %%
s.replace('love','like')
# Out:
# 'I-like-python'

# %%
s.replace('-',' ')
# Out:
# 'I love python'

# %%
s[4]
# Out:
# 'v'

# %% [markdown]
# # Rename and pictures folders

# %%
import os

# %%
os.chdir('C://Users/welcome/Desktop/snowfall')

# %%
os.listdir()
# Out:
# ['20190228_070016.jpg',
#  '20190228_070020.jpg',
#  '20190228_070023.jpg',
#  '20190228_070027.jpg',
#  '20190228_070046.mp4',
#  '20190228_070115.jpg',
#  '20190228_070203.jpg',
#  '20190228_070227.jpg',
#  '20190228_070246.jpg',
#  '20190228_070249.jpg',
#  '20190228_070257.jpg',
#  '20190228_070303.jpg',
#  '20190228_070307.jpg',
#  '20190228_070737.jpg',
#  '20190228_070740.jpg',
#  '20190228_070744.jpg',
#  '20190228_071247.jpg',
#  '20190228_071249.jpg',
#  '20190228_071250.jpg',
#  '20190228_071329.jpg',
#  '20190228_071331.jpg',
#  '20190228_071338.jpg',
#  '20190228_071422.jpg',
#  '20190228_071428.jpg',
#  '20190228_072453.jpg',
#  '20190228_072557.jpg',
#  '20190228_072602.jpg',
#  '20190228_072603.jpg',
#  '20190228_072632.jpg',
#  '20190228_073448.jpg',
#  '20190228_073449.jpg',
#  '20190228_073601.jpg',
#  '20190228_073606.jpg',
#  '20190228_073619.jpg',
#  '20190228_073623.jpg',
#  '20190228_073624.jpg',
#  '20190228_074408.jpg',
#  '20190228_074410.jpg',
# ...

# %%
def square(x):
    return x**2

# %%
square(9)
# Out:
# 81

# %%
#function is a block of code which is used to perform specific task(def)

# %%
alist=[2,3,4,5,6]

# %%
res=map(square,alist)

# %%
for i in res:
    print(i)
# Out:
# 4
# 9
# 16
# 25
# 36

# %%
list(map(square,alist))
# Out:
# [4, 9, 16, 25, 36]

# %%
list(map(square,range(1,6)))
# Out:
# [1, 4, 9, 16, 25]

# %%
list(map(cube,range(1,4)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-a38cb524df65> in <module>
# ----> 1 list(map(cube,range(1,4)))
#
# NameError: name 'cube' is not defined

# %%
def cube(x):
    return(x**3)

# %%
list(map(cube,range(1,4)))
# Out:
# [1, 8, 27]

# %%
ress=map(cube,range(1,4))

# %%
for i in ress:
    print(i)
# Out:
# 1
# 8
# 27

# %%
list(map(cube,range(10)))
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %%
def odd(o):
    return o%2==1

# %%
odd(8)
# Out:
# False

# %%
filter(odd,range(10))

# %%
list(filter(odd,range(10)))
# Out:
# [1, 3, 5, 7, 9]

# %%
for i in filter(odd,range(10)):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
