# %%
import requests
from bs4 import BeautifulSoup

# %% [raw]
# #pip install requests

# %%
base_url="https://www.phaster.com/zip_code.html"

# %%
html=requests.get(base_url)

# %%
parsed_html=BeautifulSoup(html.content,'lxml')

# %%
print(parsed_html)
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><script>(adsbygoogle = window.adsbygoogle || []).push({google_ad_client: "ca-pub-5855301837617098",enable_page_level_ads: true});</script><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, minimum-scale=1.0" name="viewport"/><meta content="456995684466633" property="fb:appid"/><meta content="190249544498250" property="fb:pages"/><meta content="c199055cb396524100e307c444ff5118" name="p:domain_verify"/><meta content="kathmandupost.ekantipur.com is Nepal's no 1 English news portal and The Kathmandu Post's official website. Started in 1993 as the first private sector broad-sheet daily in Nepal, The Kathmandu Post is also a member of Asia News Network that has over 15 members. This delivers the latest breaking news and information on latest top stories, national, international, politics, sports, business, finance, entertainment, photo-gallery, audio, video and more." name="description"/> <meta content="Nepal news in English, Kathmandu, Kathmandu post, TKP, Nepali News, Political, Science, Social, Sport, Economy, Business, Entertainment, Interview, Business news, Money, SaturdayViews, Reviews, online news nepal, Nepal news today, Nepal headline news, The Kathmandu Post, , online news, Nepal news" name="keywords"/><meta content="" name="robots"/> <meta content="English" name="language"/><meta content="info@ekantipur.com" name="reply-to"/><meta content="1 day" name="revisit-after"/><meta content="Kantipur Media Group" name="copyright"/> <meta content="tkp, the Kathmandu post, the-Kathmandu-post, Kathmandu post, kanthmandu-post, tkp.ekantipur.com, kathmandupost.ekantipur.com" name="web_author"/> <meta content="http://jcss-cdn.ekantipur.com/the-kathmandu-post/images/logo.jpg" property="og:image"/><meta content="Read online latest news and articles from Nepal." property="og:title"/><meta content="article" property="og:type"/><meta content="http://kathmandupost.ekantipur.com/" property="og:url"/><meta content="kathmandupost.ekantipur.com is Nepal's no 1 English news portal and The Kathmandu Post's official website. Started in 1993 as the first private sector broad-sheet daily in Nepal, The Kathmandu Post is also a member of Asia News Network that has over 15 members. This delivers the latest breaking news and information on latest top stories, national, international, politics, sports, business, finance, entertainment, photo-gallery, audio, video and more." property="og:description"/><meta content="@kathmandupost" property="twitter:site"/><meta content="Read online latest news and articles from Nepal." property="twitter:title"/><meta content="http://jcss-cdn.ekantipur.com/the-kathmandu-post/images/logo.jpg" property="twitter:image"/><meta content="summary" name="twitter:card"/><meta content="kathmandupost.ekantipur.com is Nepal's no 1 English news portal and The Kathmandu Post's official website. Started in 1993 as the first private sector broad-sheet daily in Nepal, The Kathmandu Post is also a member of Asia News Network that has over 15 members. This delivers the latest breaking news and information on latest top stories, national, international, politics, sports, business, finance, entertainment, photo-gallery, audio, video and more." name="twitter:description"/><meta content="@kathmandupost" name="twitter:creator"/><title> Read online latest news and articles from Nepal. - The Kathmandu Post</title><link href="http://jcss-cdn.ekantipur.com/the-kathmandu-post/images/favicon.ico" rel="icon" type="image/png"/><link href="http://jcss-cdn.ekantipur.com/the-kathmandu-post/stylesheet/common.v1.72.css" rel="stylesheet"/> <script src="http://jcss-cdn.ekantipur.com/common/javascript/jquery-lib1.js"></script><style>/*.epaper-link, #top-weather{display: none;}*/.epaper-link {display: none;}.logo .print{top:2px ...

# %%
html
# Out:
# <Response [200]>

# %%
html.content
# Out:
# b'<!doctype html><html xmlns="http://www.w3.org/1999/xhtml" lang="en" xml:lang="en"><head><script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><script>(adsbygoogle = window.adsbygoogle || []).push({google_ad_client: "ca-pub-5855301837617098",enable_page_level_ads: true});</script><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1.0"><meta property="fb:appid" content="456995684466633"/><meta property="fb:pages" content="190249544498250" /><meta name="p:domain_verify" content="c199055cb396524100e307c444ff5118"/><meta name="description" content="kathmandupost.ekantipur.com is Nepal\'s no 1 English news portal and The Kathmandu Post\'s official website. Started in 1993 as the first private sector broad-sheet daily in Nepal, The Kathmandu Post is also a member of Asia News Network that has over 15 members. This delivers the latest breaking news and information on latest top stories, national, international, politics, sports, business, finance, entertainment, photo-gallery, audio, video and more."> <meta name="keywords" content="Nepal news in English, Kathmandu, Kathmandu post, TKP, Nepali News, Political, Science, Social, Sport, Economy, Business, Entertainment, Interview, Business news, Money, SaturdayViews, Reviews, online news nepal, Nepal news today, Nepal headline news, The Kathmandu Post, , online news, Nepal news"><meta name="robots" content=""> <meta name="language" content="English"><meta name="reply-to" content="info@ekantipur.com"><meta name="revisit-after" content="1 day"><meta name="copyright" content="Kantipur Media Group"> <meta name="web_author" content="tkp, the Kathmandu post, the-Kathmandu-post, Kathmandu post, kanthmandu-post, tkp.ekantipur.com, kathmandupost.ekantipur.com"> <meta property="og:image" content="http://jcss-cdn.ekantipur.com/the-kathmandu-post/images/logo.jpg"/><meta property="og:title" content="Read online latest news and articles from Nepal."/><meta property="og:type" content="article"/><meta property="og:url" content="http://kathmandupost.ekantipur.com/"/><meta property="og:description" content="kathmandupost.ekantipur.com is Nepal\'s no 1 English news portal and The Kathmandu Post\'s official website. Started in 1993 as the first private sector broad-sheet daily in Nepal, The Kathmandu Post is also a member of Asia News Network that has over 15 members. This delivers the latest breaking news and information on latest top stories, national, international, politics, sports, business, finance, entertainment, photo-gallery, audio, video and more."/><meta content="@kathmandupost" property=\'twitter:site\'/><meta content="Read online latest news and articles from Nepal." property=\'twitter:title\'/><meta content="http://jcss-cdn.ekantipur.com/the-kathmandu-post/images/logo.jpg" property=\'twitter:image\'/><meta content="summary" name=\'twitter:card\'/><meta name="twitter:description" content="kathmandupost.ekantipur.com is Nepal\'s no 1 English news portal and The Kathmandu Post\'s official website. Started in 1993 as the first private sector broad-sheet daily in Nepal, The Kathmandu Post is also a member of Asia News Network that has over 15 members. This delivers the latest breaking news and information on latest top stories, national, international, politics, sports, business, finance, entertainment, photo-gallery, audio, video and more." /><meta name="twitter:creator" content="@kathmandupost" /><title> Read online latest news and articles from Nepal. - The Kathmandu Post</title><link rel="icon" href="http://jcss-cdn.ekantipur.com/the-kathmandu-post/images/favicon.ico" type="image/png" /><link rel="stylesheet" href="http://jcss-cdn.ekantipur.com/the-kathmandu-post/stylesheet/common.v1.72.css"/> <script src="http://jcss-cdn.ekantipur.com/common/javascript/jquery-lib1.js"></script><style>/*.epaper-link, #top-weather{display: none;}*/.epaper-link {display: none; ...

# %%
parsed_html.title.text
# Out:
# 'Valid US Cities/Zip Codes'

# %%
parsed_html.head
# Out:
# <head><title>Valid US Cities/Zip Codes</title><style type="text/css">A{text-decoration:none}A:hover{color:red;text-decoration:underline}</style></head>

# %%
parsed_html.head.meta
# Out:
# <meta charset="utf-8"/>

# %%
parsed_html.body
# Out:
# <body><style>#ekantipur-short-header{position: fixed;width: 100%;background: rgba(0,0,0,.75); top:0px; z-index:9;transition:0.5s all ease-in-out}#ekantipur-short-header .container{max-width:1200px; margin:5px auto 0;padding:0}.eklogo img{max-width:170px;margin-bottom:-5px;}#ekantipur-short-header .publications{position:relative;z-index:999;list-style:none;margin:0 0 4px; padding:0;float:right}#ekantipur-short-header .publications li{float:left;margin-right:6px;}#ekantipur-short-header .publications li a{background:url(http://jcss-cdn.ekantipur.com/ekantipur/images/sprites-hd1.png) no-repeat left;width: 30px;height: 30px;display: inline-block;text-indent: -9999px;background-size: 212px;opacity:0.8;transition:all ease 0.5s;}#ekantipur-short-header .publications li a:hover{opacity:1}#ekantipur-short-header .publications li.kantipur a{background-position: 0 0;}#ekantipur-short-header .publications li.tkp a{background-position: -30px 0;}#ekantipur-short-header .publications li.saptahik a{background-position:-61px 0;}#ekantipur-short-header .publications li.nepal a{background-position:-91px 0;}#ekantipur-short-header .publications li.nari a{background-position:-121px 0;}#ekantipur-short-header .publications li.radio-kantipur a{background-position:-152px 0;}#ekantipur-short-header .publications li.tv a{background-position:-182px 0;}#ekantipur-short-header .publications li:hover{opacity:1}#ekantipur-short-header .tooltip > .tooltip-inner {background-color: #fff; color: #000; border: 1px solid #333;padding:4px 8px; font-size: 12px;}/*@media (min-width:320px) and (max-width:599px){.eklogo img {max-width: 150px;margin-bottom:-3px;}.eklogo{float:none; text-align:center; }.publications-icon-wrapper{display:none}}@media (min-width:600px) and (max-width:767px){.eklogo img {max-width: 160px;}.eklogo, .publications-icon-wrapper{float:left; width:50%}.publications-icon-wrapper{float:right;}}*/@media (min-width:320px) and (max-width:767px){.eklogo a{ padding-left: 10px;width: 40px;overflow: hidden;float: left;transition:0.5s all ease-in}.eklogo img {max-width: 150px;margin-bottom:-3px;}#ekantipur-short-header .publications-icon-wrapper{padding:0}#ekantipur-short-header .publications li a{background-size: 190px;width: 27px;height: 26px;background-color: #ffffff;border-radius: 50%;}#ekantipur-short-header .publications{max-width: 242px;margin: 0 auto; padding:0;}#ekantipur-short-header .publications li.kantipur a{background-position: 0 0;}#ekantipur-short-header .publications li.tkp a{background-position: -27px 0;}#ekantipur-short-header .publications li.saptahik a{background-position:-55px 0;}#ekantipur-short-header .publications li.nepal a{background-position:-82px 0;}#ekantipur-short-header .publications li.nari a{background-position:-110px 0;}#ekantipur-short-header .publications li.radio-kantipur a{background-position:-136px 0;background-color: transparent;}#ekantipur-short-header .publications li.tv a{background-position:-163px 0;}#ekantipur-short-header .publications li:hover{opacity:1}}@media (min-width:550px) and (max-width:767px){.eklogo a{width:100%; padding-left:10px}.eklogo img {max-width: 160px;}.eklogo, .publications-icon-wrapper{float:left; width:50%;}}</style><div id="ekantipur-short-header"><div class="container"><div class="col-xs-3 col-sm-6 col-md-6 eklogo nopad-lt"><a href="http://www.ekantipur.com"><span><img alt="ekantipur" src="http://jcss-cdn.ekantipur.com/ekantipur/images/ekantipur-new-logo2.png"/></span></a></div><div class="col-xs-9 col-sm-6 col-md-6 publications-icon-wrapper"><div class="block-top-wrap"><div class="pub-wrap"><ul class="publications"><li class="kantipur"><a data-placement="bottom" data-toggle="tooltip" href="https://kantipurdaily.com" title="Go to kantipurdaily.com">KantipurDaily</a></li><li class="tkp"><a data-placement="bottom" data-toggle="tooltip" href="http://kathmandupost.ekantipur.com" title="Go to kathmandupost.ekantipur.com ">The Kathmandu Post</a></li><li class="saptahik"><a data-placement="bo ...

# %%
tables=parsed_html.find_all("table",attrs={"cols":3})

# %%
len(tables)
# Out:
# 2

# %%
rows=tables[0].find_all("tr")

# %%
len(rows)
# Out:
# 52

# %%
head_row=rows[0]
content_row=rows[1:]

# %%
head_row
# Out:
# <tr><td bgcolor="#006666"><b><font color="#FFFFFF" face="Arial,Helvetica">State</font></b></td><td bgcolor="#006666"><b><font color="#FFFFFF" face="Arial,Helvetica">City</font></b></td><td bgcolor="#006666"><font color="#FFFFFF" face="Arial,Helvetica"><b>ZIP Code(s)</b></font></td></tr>

# %%
column_td=head_row.find_all("td")
columns=[col.text for col in column_td]
columns
# Out:
# ['State', 'City', 'ZIP Code(s)']

# %%
values=[[data.text for data in row.find_all("td")] for row in content_row]

# %%
len(values)
# Out:
# 51

# %%
[row for row in values]
# Out:
# [['Alabama (AL)', 'Huntsville', '35801 thru 35816'],
#  ['Alaska (AK)', 'Anchorage', '99501 thru 99524'],
#  ['Arizona (AZ)', 'Phoenix', '85001 thru 85055'],
#  ['Arkansas (AR)', 'Little Rock', '72201 thru 72217'],
#  ['California (CA)',
#   'Sacramento\xa0Los Angeles\xa0Beverly Hills',
#   '94203 thru 94209\xa090001 thru 90089\xa090209 thru 90213'],
#  ['Colorado (CO)', 'Denver', '80201 thru 80239'],
#  ['Conneticut (CT)', 'Hartford', '06101 thru 06112'],
#  ['Deleware (DE)', 'Dover', '19901 thru 19905'],
#  ['District of Columbia (DC)', 'Washington', '20001 thru 20020'],
#  ['Florida (FL)',
#   'Pensacola\xa0Miami\xa0Orlando',
#   '32501 thru 32509\xa033124 thru 33190\xa032801 thru 32837'],
#  ['Georgia (GA)', 'Atlanta', '30301 thru 30381'],
#  ['Hawaii (HI)', 'Honolulu', '96801 thru 96830'],
#  ['Idaho (ID)', 'Montpelier', '83254'],
#  ['Illinois (IL)',
#   'Chicago\xa0Springfield',
#   '60601 thru 60641\xa062701 thru 62709'],
#  ['Indiana (IN)', 'Indianapolis', '46201 thru 46209'],
#  ['Iowa (IA)',
#   'Davenport\xa0Des Moines',
#   '52801 thru 52809\xa050301 thru 50323'],
#  ['Kansas (KS)', 'Wichita', '67201 thru 67221'],
#  ['Kentucky (KY)', 'Hazard', '41701- 41702'],
#  ['Lousiana (LA)', 'New Orleans', '70112 thru 70119'],
#  ['Maine (ME)', 'Freeport', '04032 thru 04034'],
#  ['Maryland (MD)', 'Baltimore', '21201 thru 21237'],
#  ['Massachusetts (MA)', 'Boston', '02101 thru 02137'],
#  ['Michigan (MI)', 'Coldwater\xa0Gaylord', '49036\xa049734 - 49735'],
#  ['Minnesota (MN)', 'Duluth', '55801 thru 55808'],
#  ['Mississippo (MS)', 'Biloxi', '39530 thru 39535'],
#  ['Missouri (MO)', 'St. Louis', '63101 thru 63141'],
#  ['Montana (MT)', 'Laurel', '59044'],
#  ['Nebraska (NE)', 'Hastings', '68901 - 68902'],
#  ['Nevada (NV)', 'Reno', '89501 thru 89513'],
#  ['New Hampshire (NH)', 'Ashland', '03217'],
#  ['New Jersey (NJ)', 'Livingston', '07039'],
#  ['New Mexico (NM)', 'Santa Fe', '87500 thru 87506'],
#  ['New York (NY)', 'New York', '10001 thru 10048'],
#  ['North Carolina (NC)', 'Oxford', '27565'],
#  ['North Dakota (ND)', 'Walhalla', '58282'],
#  ['Ohio (OH)', 'Cleveland', '44101 thru 44179'],
#  ['Oklahoma (OK)', 'Tulsa', '74101 thru 74110'],
#  ['Oregon (OR)', 'Portland', '97201 thru 97225'],
#  ['Pennsylvania (PA)', 'Pittsburgh', '15201 thru 15244'],
#  ['Rhode Island (RI)', 'Newport', '02840 - 02841'],
#  ['South Carolina (SC)', 'Camden', '29020'],
#  ['South Dakota (SD)', 'Aberdeen', '57401 - 57402'],
#  ['Tennessee (TN)', 'Nashville', '37201 thru 37222'],
#  ['Texas (TX)', 'Austin', '78701 thru 78705'],
#  ['Utah (UT)', 'Logan', '84321 thru 84323'],
#  ['Vermont (VT)', 'Killington', '05751'],
#  ['Virginia (VA)', 'Altavista', '24517'],
#  ['Washington (WA)', 'Bellevue (home of windoze)', '98004 thru 98009'],
#  ['West Virginia (WV)', 'Beaver', '25813'],
#  ['Wisconsin (WI)', 'Milwaukee', '53201 thru 53228'],
#  ['Wyoming (WY)', 'Pinedale', '82941']]

# %%
[{key:value for key, value in zip(columns,row)} for row in values]
# Out:
# [{'State': 'Alabama (AL)',
#   'City': 'Huntsville',
#   'ZIP Code(s)': '35801 thru 35816'},
#  {'State': 'Alaska (AK)',
#   'City': 'Anchorage',
#   'ZIP Code(s)': '99501 thru 99524'},
#  {'State': 'Arizona (AZ)',
#   'City': 'Phoenix',
#   'ZIP Code(s)': '85001 thru 85055'},
#  {'State': 'Arkansas (AR)',
#   'City': 'Little Rock',
#   'ZIP Code(s)': '72201 thru 72217'},
#  {'State': 'California (CA)',
#   'City': 'Sacramento\xa0Los Angeles\xa0Beverly Hills',
#   'ZIP Code(s)': '94203 thru 94209\xa090001 thru 90089\xa090209 thru 90213'},
#  {'State': 'Colorado (CO)',
#   'City': 'Denver',
#   'ZIP Code(s)': '80201 thru 80239'},
#  {'State': 'Conneticut (CT)',
#   'City': 'Hartford',
#   'ZIP Code(s)': '06101 thru 06112'},
#  {'State': 'Deleware (DE)',
#   'City': 'Dover',
#   'ZIP Code(s)': '19901 thru 19905'},
#  {'State': 'District of Columbia (DC)',
#   'City': 'Washington',
#   'ZIP Code(s)': '20001 thru 20020'},
#  {'State': 'Florida (FL)',
#   'City': 'Pensacola\xa0Miami\xa0Orlando',
#   'ZIP Code(s)': '32501 thru 32509\xa033124 thru 33190\xa032801 thru 32837'},
#  {'State': 'Georgia (GA)',
#   'City': 'Atlanta',
#   'ZIP Code(s)': '30301 thru 30381'},
#  {'State': 'Hawaii (HI)',
#   'City': 'Honolulu',
#   'ZIP Code(s)': '96801 thru 96830'},
#  {'State': 'Idaho (ID)', 'City': 'Montpelier', 'ZIP Code(s)': '83254'},
#  {'State': 'Illinois (IL)',
#   'City': 'Chicago\xa0Springfield',
#   'ZIP Code(s)': '60601 thru 60641\xa062701 thru 62709'},
#  {'State': 'Indiana (IN)',
#   'City': 'Indianapolis',
#   'ZIP Code(s)': '46201 thru 46209'},
#  {'State': 'Iowa (IA)',
#   'City': 'Davenport\xa0Des Moines',
#   'ZIP Code(s)': '52801 thru 52809\xa050301 thru 50323'},
#  {'State': 'Kansas (KS)',
#   'City': 'Wichita',
#   'ZIP Code(s)': '67201 thru 67221'},
#  {'State': 'Kentucky (KY)', 'City': 'Hazard', 'ZIP Code(s)': '41701- 41702'},
#  {'State': 'Lousiana (LA)',
#   'City': 'New Orleans',
#   'ZIP Code(s)': '70112 thru 70119'},
#  {'State': 'Maine (ME)',
#   'City': 'Freeport',
#   'ZIP Code(s)': '04032 thru 04034'},
#  {'State': 'Maryland (MD)',
#   'City': 'Baltimore',
#   'ZIP Code(s)': '21201 thru 21237'},
#  {'State': 'Massachusetts (MA)',
#   'City': 'Boston',
#   'ZIP Code(s)': '02101 thru 02137'},
#  {'State': 'Michigan (MI)',
#   'City': 'Coldwater\xa0Gaylord',
#   'ZIP Code(s)': '49036\xa049734 - 49735'},
#  {'State': 'Minnesota (MN)',
#   'City': 'Duluth',
#   'ZIP Code(s)': '55801 thru 55808'},
#  {'State': 'Mississippo (MS)',
#   'City': 'Biloxi',
#   'ZIP Code(s)': '39530 thru 39535'},
#  {'State': 'Missouri (MO)',
#   'City': 'St. Louis',
#   'ZIP Code(s)': '63101 thru 63141'},
#  {'State': 'Montana (MT)', 'City': 'Laurel', 'ZIP Code(s)': '59044'},
#  {'State': 'Nebraska (NE)',
#   'City': 'Hastings',
#   'ZIP Code(s)': '68901 - 68902'},
#  {'State': 'Nevada (NV)', 'City': 'Reno', 'ZIP Code(s)': '89501 thru 89513'},
#  {'State': 'New Hampshire (NH)', 'City': 'Ashland', 'ZIP Code(s)': '03217'},
#  {'State': 'New Jersey (NJ)', 'City': 'Livingston', 'ZIP Code(s)': '07039'},
#  {'State': 'New Mexico (NM)',
#   'City': 'Santa Fe',
#   'ZIP Code(s)': '87500 thru 87506'},
#  {'State': 'New York (NY)',
#   'City': 'New York',
#   'ZIP Code(s)': '10001 thru 10048'},
#  {'State': 'North Carolina (NC)', 'City': 'Oxford', 'ZIP Code(s)': '27565'},
#  {'State': 'North Dakota (ND)', 'City': 'Walhalla', 'ZIP Code(s)': '58282'},
#  {'State': 'Ohio (OH)',
#   'City': 'Cleveland',
#   'ZIP Code(s)': '44101 thru 44179'},
#  {'State': 'Oklahoma (OK)',
#   'City': 'Tulsa',
#   'ZIP Code(s)': '74101 thru 74110'},
#  {'State': 'Oregon (OR)',
#   'City': 'Portland',
#   'ZIP Code(s)': '97201 thru 97225'},
#  {'State': 'Pennsylvania (PA)',
#   'City': 'Pittsburgh',
#   'ZIP Code(s)': '15201 thru 15244'},
#  {'State': 'Rhode Island (RI)',
#   'City': 'Newport',
#   'ZIP Code(s)': '02840 - 02841'},
#  {'State': 'South Carolina (SC)', 'City': 'Camden', 'ZIP Code(s)': '29020'},
#  {'State': 'South Dakota (SD)',
#   'City': 'Aberdeen',
#   'ZIP Code(s)': '57401 - 57402'},
#  {'State': 'Tennessee (TN)',
#   'City': 'Nashville',
#   'ZIP Code(s)': '37201 thru 37222'},
#  {'State': 'Texas (TX)', 'City': 'Austin', 'ZIP Code(s)': '78701 thru 78705'},
#  {'State': 'Utah (UT)', 'City': 'Logan', 'ZIP Code(s)': '84321 thru 84323'},
#  {'State': 'Vermont (VT)', 'City': 'Killington', 'ZIP Code(s)': '05751'},
#  {'State': 'Virginia (VA)', 'City': 'Altavista', 'ZIP Code(s)': '24517'},
#  {'State': 'Washington (WA)',
#   'City': 'Bellevue (home of windoze)',
#   'ZIP Code(s)': '98004 thru 98009'},
#  {'State': 'West Virginia (WV)', 'City': 'Beaver', 'ZIP Code(s)': '25813'},
#  {'State': 'Wisconsin (WI)',
#   'City': 'Milwaukee',
#   'ZIP Code(s)': '53201 thru 53228'},
#  {'State': 'Wyoming (WY)', 'City': 'Pinedale', 'ZIP Code(s)': '82941'}]

# %%
[dict]
